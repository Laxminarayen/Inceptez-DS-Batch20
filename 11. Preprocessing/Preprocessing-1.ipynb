# %%
#Data preprocessing 
#1. Feature engineering - Extract maximum information from the data and feed it inside "Model"
    #Model - Black box - O/p - Predictions - Machine Learning Models
#2. Feature Learning - predictions

# %%
#Core - Working on ML techniques - Neural Networks - Modules
#Applied ML - CV, NLP - Neutwork for Images

# %%
#Rows 
#Cols - Part of columns are rows
    - Missing values (univariate analysis - fix it)

# %%
Sq.ft, Price of tiles -> price per sq. ft

# %%
import pandas as pd

# %%
'''
NaN: '', '#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan',
'1.#IND', '1.#QNAN', '<NA>', 'N/A', 'NA', 'NULL', 'NaN', 'n/a',
'nan', 'null'.
'''
data = pd.read_csv("data/companytest.csv",na_values = ['Laxmi'])

# %%
#NaN - Not a number, #N/A, 
data.shape
# Out:
# (33, 3)

# %%
1. EDA - Exploratory Data Analytics (Explore the data - Understand the data via Analysis)
2. Fix all the issues!! - Fixing issues that are problematic when building my model

# %% [markdown]
# ## 1. Dropping the NA values
# ## 2. Filling NA values - Missing data imputation - Measures of central Tendency - Mean / Median / Mode based imputation.
# ## 3. Filling the NA - Central Tendency - Grouping - Aggregation
# ## 4. K - Nearest Neighbor imputation
# ###### 5. Testing method - to impute

# %%
#1. Row wise operation - Drop na
#2. Column wise operation - Drop Columns if missing values > 30%
    #1. more than 70-80% missing values - drop

# %%
data.isna().sum()
# Out:
# Company    3
# Age        4
# Salary     7
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Company  30 non-null     object
#  1   Age      29 non-null     float64
#  2   Salary   26 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 920.0+ bytes

# %%
total_null = data.isnull().sum().sort_values(ascending = False)
percent = ((data.isnull().sum())/data.shape[0]).sort_values(ascending = False)
missing_value_data = pd.concat([total_null, percent],keys = ['Total','Percent'])

# %%
missing_value_data
# Out:
# Total    Salary     7.000000
#          Age        4.000000
#          Company    3.000000
# Percent  Salary     0.212121
#          Age        0.121212
#          Company    0.090909
# dtype: float64

# %%
data
# Out:
#    Company    Age     Salary
# 0        b   40.0  9000000.0
# 1        d  300.0     1000.0
# 2        a   30.0     -400.0
# 3      'a'   20.0        NaN
# 4        c   30.0        NaN
# 5      'a'   35.0     2300.0
# 6        c   40.0     3000.0
# 7        a   23.0     4000.0
# 8        c    NaN     5000.0
# 9        a    NaN     6000.0
# 10     'c'   23.0     7000.0
# 11       a   34.0     8000.0
# 12       b   45.0     9000.0
# 13       b   23.0        NaN
# 14       b   34.0     1089.0
# 15       b   45.0        NaN
# 16       b   18.0     1234.0
# 17     NaN   40.0     3000.0
# 18       a   23.0     3000.0
# 19       c   23.0     3030.0
# 20       a   34.0     5000.0
# 21     NaN   22.0        NaN
# 22       c   32.0        NaN
# 23       a   37.0     3045.0
# 24       c   50.0     3184.0
# 25       a   21.0     4824.0
# 26       c    NaN     5835.0
# 27     NaN    NaN     7084.0
# 28       c   23.0     8943.0
# 29       a   34.0     8345.0
# 30       b   45.0     9284.0
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#    Company    Age     Salary
# 0        b   40.0  9000000.0
# 1        d  300.0     1000.0
# 2        a   30.0     -400.0
# 5      'a'   35.0     2300.0
# 6        c   40.0     3000.0
# 7        a   23.0     4000.0
# 10     'c'   23.0     7000.0
# 11       a   34.0     8000.0
# 12       b   45.0     9000.0
# 14       b   34.0     1089.0
# 16       b   18.0     1234.0
# 18       a   23.0     3000.0
# 19       c   23.0     3030.0
# 20       a   34.0     5000.0
# 23       a   37.0     3045.0
# 24       c   50.0     3184.0
# 25       a   21.0     4824.0
# 28       c   23.0     8943.0
# 29       a   34.0     8345.0
# 30       b   45.0     9284.0
# 32       b   35.0     2034.0

# %%
data = data.dropna(subset = ['Company'])

# %%
data = pd.read_csv("data/companytest.csv")

# %%
#Shallow copy
temp = data

# %%
data
# Out:
#    Company    Age     Salary
# 0        b  Hello  9000000.0
# 1        d  Hello     1000.0
# 2        a  Hello     -400.0
# 3      'a'  Hello        NaN
# 4        c  Hello        NaN
# 5      'a'  Hello     2300.0
# 6        c  Hello     3000.0
# 7        a  Hello     4000.0
# 8        c  Hello     5000.0
# 9        a  Hello     6000.0
# 10     'c'  Hello     7000.0
# 11       a  Hello     8000.0
# 12       b  Hello     9000.0
# 13       b  Hello        NaN
# 14       b  Hello     1089.0
# 15       b  Hello        NaN
# 16       b  Hello     1234.0
# 17     NaN  Hello     3000.0
# 18       a  Hello     3000.0
# 19       c  Hello     3030.0
# 20       a  Hello     5000.0
# 21     NaN  Hello        NaN
# 22       c  Hello        NaN
# 23       a  Hello     3045.0
# 24       c  Hello     3184.0
# 25       a  Hello     4824.0
# 26       c  Hello     5835.0
# 27     NaN  Hello     7084.0
# 28       c  Hello     8943.0
# 29       a  Hello     8345.0
# 30       b  Hello     9284.0
# ...

# %%
temp['Age'] = "Hello"

# %%
temp
# Out:
#    Company    Age     Salary
# 0        b  Hello  9000000.0
# 1        d  Hello     1000.0
# 2        a  Hello     -400.0
# 3      'a'  Hello        NaN
# 4        c  Hello        NaN
# 5      'a'  Hello     2300.0
# 6        c  Hello     3000.0
# 7        a  Hello     4000.0
# 8        c  Hello     5000.0
# 9        a  Hello     6000.0
# 10     'c'  Hello     7000.0
# 11       a  Hello     8000.0
# 12       b  Hello     9000.0
# 13       b  Hello        NaN
# 14       b  Hello     1089.0
# 15       b  Hello        NaN
# 16       b  Hello     1234.0
# 17     NaN  Hello     3000.0
# 18       a  Hello     3000.0
# 19       c  Hello     3030.0
# 20       a  Hello     5000.0
# 21     NaN  Hello        NaN
# 22       c  Hello        NaN
# 23       a  Hello     3045.0
# 24       c  Hello     3184.0
# 25       a  Hello     4824.0
# 26       c  Hello     5835.0
# 27     NaN  Hello     7084.0
# 28       c  Hello     8943.0
# 29       a  Hello     8345.0
# 30       b  Hello     9284.0
# ...

# %%
#Deep copy
data_cpy = data.copy()

# %%
data_cpy['Age'] = 'Hello'

# %%
data_cpy
# Out:
#    Company    Age     Salary
# 0        b  Hello  9000000.0
# 1        d  Hello     1000.0
# 2        a  Hello     -400.0
# 3      'a'  Hello        NaN
# 4        c  Hello        NaN
# 5      'a'  Hello     2300.0
# 6        c  Hello     3000.0
# 7        a  Hello     4000.0
# 8        c  Hello     5000.0
# 9        a  Hello     6000.0
# 10     'c'  Hello     7000.0
# 11       a  Hello     8000.0
# 12       b  Hello     9000.0
# 13       b  Hello        NaN
# 14       b  Hello     1089.0
# 15       b  Hello        NaN
# 16       b  Hello     1234.0
# 17     NaN  Hello     3000.0
# 18       a  Hello     3000.0
# 19       c  Hello     3030.0
# 20       a  Hello     5000.0
# 21     NaN  Hello        NaN
# 22       c  Hello        NaN
# 23       a  Hello     3045.0
# 24       c  Hello     3184.0
# 25       a  Hello     4824.0
# 26       c  Hello     5835.0
# 27     NaN  Hello     7084.0
# 28       c  Hello     8943.0
# 29       a  Hello     8345.0
# 30       b  Hello     9284.0
# ...

# %%
data
# Out:
#    Company    Age     Salary
# 0        b   40.0  9000000.0
# 1        d  300.0     1000.0
# 2        a   30.0     -400.0
# 3      'a'   20.0        NaN
# 4        c   30.0        NaN
# 5      'a'   35.0     2300.0
# 6        c   40.0     3000.0
# 7        a   23.0     4000.0
# 8        c    NaN     5000.0
# 9        a    NaN     6000.0
# 10     'c'   23.0     7000.0
# 11       a   34.0     8000.0
# 12       b   45.0     9000.0
# 13       b   23.0        NaN
# 14       b   34.0     1089.0
# 15       b   45.0        NaN
# 16       b   18.0     1234.0
# 17     NaN   40.0     3000.0
# 18       a   23.0     3000.0
# 19       c   23.0     3030.0
# 20       a   34.0     5000.0
# 21     NaN   22.0        NaN
# 22       c   32.0        NaN
# 23       a   37.0     3045.0
# 24       c   50.0     3184.0
# 25       a   21.0     4824.0
# 26       c    NaN     5835.0
# 27     NaN    NaN     7084.0
# 28       c   23.0     8943.0
# 29       a   34.0     8345.0
# 30       b   45.0     9284.0
# ...

# %%
data.describe()
# Out:
#               Age        Salary
# count   29.000000  2.600000e+01
# mean    40.758621  3.505320e+05
# std     50.644881  1.764154e+06
# min     18.000000 -4.000000e+02
# 25%     23.000000  3.000000e+03
# 50%     34.000000  4.412000e+03
# 75%     40.000000  7.063000e+03
# max    300.000000  9.000000e+06

# %%
data.describe(include = 'all')
# Out:
#        Company         Age        Salary
# count       30   29.000000  2.600000e+01
# unique       6         NaN           NaN
# top          b         NaN           NaN
# freq         9         NaN           NaN
# mean       NaN   40.758621  3.505320e+05
# std        NaN   50.644881  1.764154e+06
# min        NaN   18.000000 -4.000000e+02
# 25%        NaN   23.000000  3.000000e+03
# 50%        NaN   34.000000  4.412000e+03
# 75%        NaN   40.000000  7.063000e+03
# max        NaN  300.000000  9.000000e+06

# %%
data.info()

# %%
data.head()
# Out:
#   Company    Age     Salary
# 0       b   40.0  9000000.0
# 1       d  300.0     1000.0
# 2       a   30.0     -400.0
# 3     'a'   20.0        NaN
# 4       c   30.0        NaN

# %%
#information notavailable itself as an information
data['Company'] = data['Company'].fillna("Not specified")

# %%
data
# Out:
#           Company    Age     Salary
# 0               b   40.0  9000000.0
# 1               d  300.0     1000.0
# 2               a   30.0     -400.0
# 3             'a'   20.0        NaN
# 4               c   30.0        NaN
# 5             'a'   35.0     2300.0
# 6               c   40.0     3000.0
# 7               a   23.0     4000.0
# 8               c    NaN     5000.0
# 9               a    NaN     6000.0
# 10            'c'   23.0     7000.0
# 11              a   34.0     8000.0
# 12              b   45.0     9000.0
# 13              b   23.0        NaN
# 14              b   34.0     1089.0
# 15              b   45.0        NaN
# 16              b   18.0     1234.0
# 17  Not specified   40.0     3000.0
# 18              a   23.0     3000.0
# 19              c   23.0     3030.0
# 20              a   34.0     5000.0
# 21  Not specified   22.0        NaN
# 22              c   32.0        NaN
# 23              a   37.0     3045.0
# 24              c   50.0     3184.0
# ...

# %%
import numpy as np

# %%
#The better after fixing irregularity
data_cpy = data.copy()
data_cpy['Company'] = data_cpy['Company'].fillna("empty")
data_cpy['Company'] = data_cpy['Company'].apply(lambda x: x. replace("'",''))
print(data_cpy)
data_cpy['Company'] = data_cpy['Company'].apply(lambda x: x.replace('empty', data_cpy['Company'].mode()[0]))
# Out:
#    Company    Age     Salary
# 0        b   40.0  9000000.0
# 1        d  300.0     1000.0
# 2        a   30.0     -400.0
# 3        a   20.0        NaN
# 4        c   30.0        NaN
# 5        a   35.0     2300.0
# 6        c   40.0     3000.0
# 7        a   23.0     4000.0
# 8        c    NaN     5000.0
# 9        a    NaN     6000.0
# 10       c   23.0     7000.0
# 11       a   34.0     8000.0
# 12       b   45.0     9000.0
# 13       b   23.0        NaN
# 14       b   34.0     1089.0
# 15       b   45.0        NaN
# 16       b   18.0     1234.0
# 17   empty   40.0     3000.0
# 18       a   23.0     3000.0
# 19       c   23.0     3030.0
# 20       a   34.0     5000.0
# 21   empty   22.0        NaN
# 22       c   32.0        NaN
# 23       a   37.0     3045.0
# 24       c   50.0     3184.0
# 25       a   21.0     4824.0
# 26       c    NaN     5835.0
# 27   empty    NaN     7084.0
# 28       c   23.0     8943.0
# 29       a   34.0     8345.0
# 30       b   45.0     9284.0
# ...

# %%
data_cpy
# Out:
#    Company    Age     Salary
# 0        b   40.0  9000000.0
# 1        d  300.0     1000.0
# 2        a   30.0     -400.0
# 3        a   20.0        NaN
# 4        c   30.0        NaN
# 5        a   35.0     2300.0
# 6        c   40.0     3000.0
# 7        a   23.0     4000.0
# 8        c    NaN     5000.0
# 9        a    NaN     6000.0
# 10       c   23.0     7000.0
# 11       a   34.0     8000.0
# 12       b   45.0     9000.0
# 13       b   23.0        NaN
# 14       b   34.0     1089.0
# 15       b   45.0        NaN
# 16       b   18.0     1234.0
# 17       a   40.0     3000.0
# 18       a   23.0     3000.0
# 19       c   23.0     3030.0
# 20       a   34.0     5000.0
# 21       a   22.0        NaN
# 22       c   32.0        NaN
# 23       a   37.0     3045.0
# 24       c   50.0     3184.0
# 25       a   21.0     4824.0
# 26       c    NaN     5835.0
# 27       a    NaN     7084.0
# 28       c   23.0     8943.0
# 29       a   34.0     8345.0
# 30       b   45.0     9284.0
# ...

# %%
data_cpy
# Out:
#    Company    Age     Salary
# 0        b   40.0  9000000.0
# 1        d  300.0     1000.0
# 2        a   30.0     -400.0
# 3        a   20.0        NaN
# 4        c   30.0        NaN
# 5        a   35.0     2300.0
# 6        c   40.0     3000.0
# 7        a   23.0     4000.0
# 8        c    NaN     5000.0
# 9        a    NaN     6000.0
# 10       c   23.0     7000.0
# 11       a   34.0     8000.0
# 12       b   45.0     9000.0
# 13       b   23.0        NaN
# 14       b   34.0     1089.0
# 15       b   45.0        NaN
# 16       b   18.0     1234.0
# 17       a   40.0     3000.0
# 18       a   23.0     3000.0
# 19       c   23.0     3030.0
# 20       a   34.0     5000.0
# 21       a   22.0        NaN
# 22       c   32.0        NaN
# 23       a   37.0     3045.0
# 24       c   50.0     3184.0
# 25       a   21.0     4824.0
# 26       c    NaN     5835.0
# 27       a    NaN     7084.0
# 28       c   23.0     8943.0
# 29       a   34.0     8345.0
# 30       b   45.0     9284.0
# ...

# %%
Harmony = Harmony_A, Harmony_B....
'Harmony'

# %%
#Without handling the irregularities - replace throws an error - handle this irregularity and use the fillna

# %%
data_cpy
data_cpy['Company'] = data_cpy['Company'].fillna(data.describe(include = 'all')['Company']['top'])

# %%
data_cpy
data_cpy['Company'] = data_cpy['Company'].fillna(data_cpy['Company'].mode()[0])

# %%
data_cpy['Company'] = data_cpy['Company'].apply(lambda x: x.replace("'",''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-16ab3ead6072> in <module>
# ----> 1 data_cpy['Company'] = data_cpy['Company'].apply(lambda x: x.replace("'",''))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-66-16ab3ead6072> in <lambda>(x)
# ----> 1 data_cpy['Company'] = data_cpy['Company'].apply(lambda x: x.replace("'",''))
#
# AttributeError: 'float' object has no attribute 'replace'

# %%
#We are trying to closely estimate the missing values 
#We are trying to get the values closer to the missing values - Predict it 
#We are trying to estimate the missing values

# %%
train_data = pd.read_csv("data/train.csv")

# %%
train_data.isna().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data_cpy = data.copy()

# %%
data_cpy['Age'].fillna(data['Age'].median())
# Out:
# 0      40.0
# 1     300.0
# 2      30.0
# 3      20.0
# 4      30.0
# 5      35.0
# 6      40.0
# 7      23.0
# 8      34.0
# 9      34.0
# 10     23.0
# 11     34.0
# 12     45.0
# 13     23.0
# 14     34.0
# 15     45.0
# 16     18.0
# 17     40.0
# 18     23.0
# 19     23.0
# 20     34.0
# 21     22.0
# 22     32.0
# 23     37.0
# 24     50.0
# 25     21.0
# 26     34.0
# 27     34.0
# 28     23.0
# 29     34.0
# 30     45.0
# 31     23.0
# 32     35.0
# Name: Age, dtype: float64

# %%
data_cpy['Age'].fillna(data_cpy.groupby('Company')['Age'].transform('median'))
# Out:
# 0      40.0
# 1     300.0
# 2      30.0
# 3      20.0
# 4      30.0
# 5      35.0
# 6      40.0
# 7      23.0
# 8      30.0
# 9      32.0
# 10     23.0
# 11     34.0
# 12     45.0
# 13     23.0
# 14     34.0
# 15     45.0
# 16     18.0
# 17     40.0
# 18     23.0
# 19     23.0
# 20     34.0
# 21     22.0
# 22     32.0
# 23     37.0
# 24     50.0
# 25     21.0
# 26     30.0
# 27     32.0
# 28     23.0
# 29     34.0
# 30     45.0
# 31     23.0
# 32     35.0
# Name: Age, dtype: float64

# %%
data_cpy.loc[data_cpy['Company']=='d']
# Out:
#   Company    Age  Salary
# 1       d  300.0  1000.0

# %%
data_cpy.groupby('Company')['Age'].agg(np.median)
# Out:
# Company
# a     32.0
# b     35.0
# c     30.0
# d    300.0
# Name: Age, dtype: float64

# %%
#Unhealthy Duplicates 
Ticket_number         decription      text                                  via
1234566               unhappy         Very sad to recieve broken product    SMS
1234565               unhappy         Very sad to recieve broken product    Mail
1234567               unhappy         Very sad to recieve broken product    Chat 
1234568               unhappy         Very sad to recieve broken product    Voice Mail 
1234569               unhappy         Very sad to recieve broken product    CRM - Tool
1234556               Very very unhpy I have received a broken product hav. Voice
#Embedding space - Converting the text - vectors - Distance based estimates

# %%
data.drop_duplicates(subset = ['Cust_name','description','text'])

# %% [markdown]
# ### Outliers

# %%
num_columns = data.select_dtypes(include = np.number).columns[:]

# %%
num_columns
# Out:
# Index(['Age', 'Salary'], dtype='object')

# %%
for col_name in num_columns:
    print(col_name)
    q1 = data[col_name].quantile(0.25)
    q3 = data[col_name].quantile(0.75)
    iqr = q3-q1
    
    low = q1-1.5*iqr
    high = q3+1.5*iqr
    if col_name == "Salary":
        low = 100.0
    print("The lower whisker:",low)
    print("The upper whisker:",high)
    data.loc[(data[col_name] < low) | (data[col_name]>high),col_name] = data[col_name].median()
# Out:
# Age
# The lower whisker: 2.0
# The upper whisker: 58.0
# Salary
# The lower whisker: 100
# The upper whisker: 12375.0

# %%
data
# Out:
#    Company   Age  Salary
# 0        b  40.0  4412.0
# 1        d  34.0  1000.0
# 2        a  30.0  4206.0
# 3      'a'  20.0     NaN
# 4        c  30.0     NaN
# 5      'a'  35.0  2300.0
# 6        c  40.0  3000.0
# 7        a  23.0  4000.0
# 8        c   NaN  5000.0
# 9        a   NaN  6000.0
# 10     'c'  23.0  7000.0
# 11       a  34.0  8000.0
# 12       b  45.0  9000.0
# 13       b  23.0     NaN
# 14       b  34.0  1089.0
# 15       b  45.0     NaN
# 16       b  18.0  1234.0
# 17     NaN  40.0  3000.0
# 18       a  23.0  3000.0
# 19       c  23.0  3030.0
# 20       a  34.0  5000.0
# 21     NaN  22.0     NaN
# 22       c  32.0     NaN
# 23       a  37.0  3045.0
# 24       c  50.0  3184.0
# 25       a  21.0  4824.0
# 26       c   NaN  5835.0
# 27     NaN   NaN  7084.0
# 28       c  23.0  8943.0
# 29       a  34.0  8345.0
# 30       b  45.0  9284.0
# 31       b  23.0     NaN
# 32       b  35.0  2034.0

# %%
#Can you please try???
#impute the missing values now with mean, Groupby company - mean
