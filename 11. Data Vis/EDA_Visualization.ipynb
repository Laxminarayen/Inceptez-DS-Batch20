# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns

# %%
fifa = pd.read_csv("data-for-datavis/fifa.csv",index_col= 'Date',parse_dates=True)

# %%
fifa

# %%
sns.lineplot(data = fifa)

# %%
plt.figure(figsize = (16,7))
sns.lineplot(data = fifa)

# %%
#Load the data 
#Examine the data 
#Plot to confirm the pattern 
#pre-processing

# %%
sns.lineplot(data= fifa['ARG'], color = 'blue')

# %%
sns.lineplot(data= fifa['ARG'], color = 'g')

# %%
spotify = pd.read_csv("data-for-datavis/spotify.csv",index_col='Date',parse_dates=True)

# %%
plt.figure(figsize = (16,7))
plt.ticklabel_format(style = 'plain')
plt.xlabel("Dates from 2017-2018")
plt.ylabel("Views")
plt.title("Popularity of Shape of You between 2017 and 2018")
sns.lineplot(data= spotify['Shape of You'], color = 'g')
# Out:
# <AxesSubplot: title={'center': 'Popularity of Shape of You between 2017 and 2018'}, xlabel='Dates from 2017-2018', ylabel='Views'>

# %%
spotify['Date'] = spotify['Date'].astype('Datetime64')
date_values = spotify['Date]'.dt.strftime("%Y-%m-%d").sort_values().unique

# %%
date_values
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
date_values
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
spotify.Date.tolist()

# %%
ax.set_xticklabels?
# Out:
# Signature: ax.set_xticklabels(labels, *, fontdict=None, minor=False, **kwargs)
# Docstring:
# Set the xaxis' labels with list of string labels.
#
# .. warning::
#     This method should only be used after fixing the tick positions
#     using `.Axes.set_xticks`. Otherwise, the labels may end up in
#     unexpected positions.
#
# Parameters
# ----------
# labels : list of str
#     The label texts.
#
# fontdict : dict, optional
#     A dictionary controlling the appearance of the ticklabels.
#     The default *fontdict* is::
#
#        {'fontsize': rcParams['axes.titlesize'],
#         'fontweight': rcParams['axes.titleweight'],
#         'verticalalignment': 'baseline',
#         'horizontalalignment': loc}
#
# minor : bool, default: False
#     Whether to set the minor ticklabels rather than the major ones.
#
# Returns
# -------
# list of `.Text`
#     The labels.
#
# Other Parameters
# ----------------
# **kwargs : `~.text.Text` properties.
# ...

# %%
spotify = pd.read_csv("data-for-datavis/spotify.csv")

# %%
spotify
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
fig, ax = plt.subplots(figsize =(12,6))


spotify['Date']= spotify['Date'].astype("datetime64")
date_values = spotify['Date'].dt.strftime('%Y-%m-%d').sort_values().unique()


fig = sns.lineplot(x = 'Date',y = 'Shape of You',data = spotify)
#ax.set_xticklabels(labels =date_values,rotation = 45,ha='right')

# %%
#Bar Plot

# %%
flight_delay = pd.read_csv("data-for-datavis/flight_delays.csv")

# %%
flight_delay
# Out:
#     Month        AA        AS         B6        DL         EV         F9  \
# 0       1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1       2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2       3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3       4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4       5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 5       6  8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 6       7  3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 7       8  3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 8       9 -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 9      10 -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 10     11  0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 11     12  4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
fig,ax = plt.subplots(figsize = (10,7))
fig= sns.barplot(x = flight_delay['Month'], y = flight_delay['AA'])
plt.title("Avg. Arrival Delay - Spirit")
plt.ylabel("Arrival delya in mins.")
month_lst = ['Jan','Feb','March','April','May','June','Jul','Aug','Sep','Oct','Nov','Dec']
ax.set_xticklabels(labels =month_lst)
# Out:
# [Text(0, 0, 'Jan'),
#  Text(1, 0, 'Feb'),
#  Text(2, 0, 'March'),
#  Text(3, 0, 'April'),
#  Text(4, 0, 'May'),
#  Text(5, 0, 'June'),
#  Text(6, 0, 'Jul'),
#  Text(7, 0, 'Aug'),
#  Text(8, 0, 'Sep'),
#  Text(9, 0, 'Oct'),
#  Text(10, 0, 'Nov'),
#  Text(11, 0, 'Dec')]

# %%
#Try for B6
fig,ax = plt.subplots(figsize = (10,7))
fig= sns.barplot(x = flight_delay['Month'], y = flight_delay['AA'])
plt.title("Avg. Arrival Delay - Spirit")
plt.ylabel("Arrival delya in mins.")
month_lst = ['Jan','Feb','March','April','May','June','Jul','Aug','Sep','Oct','Nov','Dec']
ax.set_xticklabels(labels =month_lst)

# %%
#Heatmap 
flight_delay = pd.read_csv("data-for-datavis/flight_delays.csv")

# %%
sns.heatmap(data = flight_delay)
# Out:
# <AxesSubplot: ylabel='Month'>

# %%
plt.figure(figsize=(10,6))
corr = flight_delay.corr()

ax  = sns.heatmap(corr, vmin = -1,vmax = 1,center = 0)

# %%
plt.figure(figsize=(10,6))
corr = flight_delay.corr()

ax  = sns.heatmap(corr, vmin = -1,vmax = 1,center = 0,annot = True)

# %%
#Scatter plot - direct relationhsip visualization

# %%
insurance = pd.read_csv("data-for-datavis/insurance.csv")

# %%
insurance.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
sns.scatterplot(x = insurance['bmi'],y= insurance['charges'])
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='charges'>

# %%
sns.regplot(x = insurance['bmi'],y= insurance['charges'])
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='charges'>

# %%
sns.scatterplot(x = insurance['bmi'],y= insurance['charges'],hue = insurance['smoker'])
# Out:
# <AxesSubplot: xlabel='bmi', ylabel='charges'>

# %%
sns.lmplot(x = 'bmi',y= 'charges',hue = 'smoker',data = insurance)

# %%
sns.swarmplot(x = 'smoker',y= 'charges',data = insurance)
# Out:
# /Users/laxminarayen/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot: xlabel='smoker', ylabel='charges'>

# %%
sns.pairplot(insurance)

# %%
#Distribution from the data
iris = pd.read_csv("data-for-datavis/iris.csv",index_col='Id')

# %%
iris
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.distplot?
# Out:
# Signature:
# sns.distplot(
#     a=None,
#     bins=None,
#     hist=True,
#     kde=True,
#     rug=False,
#     fit=None,
#     hist_kws=None,
#     kde_kws=None,
#     rug_kws=None,
#     fit_kws=None,
#     color=None,
#     vertical=False,
#     norm_hist=False,
#     axlabel=None,
#     label=None,
#     ax=None,
#     x=None,
# )
# Docstring:
# DEPRECATED: Flexibly plot a univariate distribution of observations.
#
# .. warning::
#    This function is deprecated and will be removed in a future version.
#    Please adapt your code to use one of two new functions:
#
#    - :func:`displot`, a figure-level function with a similar flexibility
#      over the kind of plot to draw
#    - :func:`histplot`, an axes-level function for plotting histograms,
#      including with kernel density smoothing
#
# This function combines the matplotlib ``hist`` function (with automatic
# calculation of a good default bin size) with the seaborn :func:`kdeplot`
# ...

# %%
sns.distplot(a = iris['Sepal Length (cm)'],kde = False)
# Out:
# /Users/laxminarayen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='Sepal Length (cm)'>

# %%
sns.distplot(a = iris['Sepal Length (cm)'],kde = True)
# Out:
# /Users/laxminarayen/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot: xlabel='Sepal Length (cm)', ylabel='Density'>

# %%
sns.kdeplot(data = iris['Sepal Length (cm)'],shade = True)
# Out:
# <AxesSubplot: xlabel='Sepal Length (cm)', ylabel='Density'>

# %%
sns.jointplot(x = iris['Sepal Length (cm)'], y = iris['Sepal Width (cm)'],kind = "kde")

# %%
sns.set_style('dark')
sns.jointplot(x = iris['Sepal Length (cm)'], y = iris['Sepal Width (cm)'],kind = "kde")

# %%
sns.set_style('whitegrid')
sns.jointplot(x = iris['Sepal Length (cm)'], y = iris['Sepal Width (cm)'],kind = "kde")

# %%
sns.set_style('darkgrid')
sns.jointplot(x = iris['Sepal Length (cm)'], y = iris['Sepal Width (cm)'],kind = "kde")

# %%
ax = sns.boxplot(data = iris)

# %%
ax = sns.boxplot(data = iris, orient = 'h')

# %%
ax = sns.boxplot(data = iris, orient = 'h',palette='Set2',color = '.25')

# %% [markdown]
# ![image.png](attachment:image.png)
